# %% [markdown]
# # **1. SCRAPPING DATA**

# %% [markdown]
# #Import Library
# Langkah pertama yang perlu dilakukan adalah mengimpor library yang akan digunakan. Kita akan menggunakan:
# *   **pandas** untuk memproses dan menyimpan data dalam bentuk tabel.
# *   **requests** untuk mengirim permintaan HTTP,
# *   **BeautifulSoup** dari library bs4 untuk melakukan parsing terhadap konten HTML,
# pandas untuk memproses dan menyimpan data dalam bentuk tabel.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Menentukan URL dan Menyusun Header Permintaan
# Langkah berikutnya adalah menetapkan URL halaman web yang akan diambil datanya (scraping). Dalam contoh ini, targetnya adalah halaman pertama dari hasil pencarian pekerjaan Data Scientist di situs pekerjaan Jobstreet. Disini saya hanya ingin mengambil data lowongan pekerjaan dengan gaji minimal 2 juta, full time, dan terdaftar di 30 hari terakhir.

# %%
url = 'https://id.jobstreet.com/id/Data-Scientist-jobs/full-time?daterange=31&salaryrange=2000000-&salarytype=monthly&workarrangement=1%2C3%2C2'

# %% [markdown]
# Setelah URL ditentukan, kita juga perlu menyiapkan header untuk permintaan HTTP. Header ini berguna agar permintaan yang dikirim tampak seperti berasal dari browser asli, sehingga dapat menghindari pemblokiran karena terdeteksi sebagai aktivitas bot.

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.90"
}

# %% [markdown]
# - **User-Agent** adalah informasi yang menunjukkan jenis browser yang digunakan. Dengan menyertakan User-Agent dalam header, kita memberi tahu server bahwa permintaan berasal dari browser tertentu—misalnya Google Chrome—sehingga lebih kecil kemungkinannya untuk ditolak.

# %% [markdown]
# #Mengirim Permintaan HTTP
# Setelah URL dan header disiapkan, kita dapat mengirimkan permintaan ke website menggunakan requests.get() untuk mengambil konten dari halaman tersebut.

# %%
s = requests.session()
s.headers.update(headers)

page = s.get(url)

# %% [markdown]
# - **Session** memungkinkan kita mengelola permintaan dan header secara lebih efisien, terutama jika kita melakukan beberapa permintaan ke situs yang sama.
# - **get()** adalah metode untuk mengirim permintaan HTTP GET ke URL yang telah ditentukan dan menerima respons berupa isi halaman.

# %% [markdown]
# # Memeriksa Status Permintaan (Request Status)
# Sebelum memproses data dari halaman web, sangat penting untuk memastikan bahwa permintaan HTTP yang kita kirim berhasil. Ini bisa diketahui melalui kode status (status code) yang diberikan dalam respons.

# %%
if page.status_code == 200:
    print("Request berhasil!")
else:
    print(f"Request gagal dengan kode status: {page.status_code}")
# Out:
# Request berhasil!

# %% [markdown]
# status_code: Merupakan atribut dari respons HTTP yang menunjukkan status dari permintaan.
#
# - 200 menandakan bahwa permintaan berhasil dan halaman berhasil dimuat.
#
# - Kode selain 200, seperti 404 (Not Found) atau 403 (Forbidden), menunjukkan bahwa terjadi kesalahan—entah karena URL tidak valid, halaman tidak tersedia, atau akses dibatasi.
#
# Sebagai langkah verifikasi, kita bisa menggunakan kondisi page.status_code == 200. Jika hasilnya bukan 200, maka perlu dilakukan pengecekan lebih lanjut terhadap URL atau penyesuaian pada konfigurasi permintaan.

# %% [markdown]
# #Memproses HTML dengan BeautifulSoup
# Jika permintaan HTTP berhasil (status code 200), langkah selanjutnya adalah mengambil isi halaman dan memprosesnya menggunakan BeautifulSoup.

# %%
soup = BeautifulSoup(page.text, "lxml")
joblist = soup.find('div', class_='_32fem00 _1nh354wo')

# %% [markdown]
# - **BeautifulSoup** berfungsi untuk mengurai (parse) konten HTML dan mengubahnya menjadi objek Python yang mudah ditelusuri dan dimanipulasi.
#
# - Metode **find()** digunakan untuk mencari elemen HTML tertentu berdasarkan tag dan class. Dalam konteks ini, kita akan mencari elemen (div) yang memuat daftar lowongan pekerjaan.
#
# Dengan pendekatan ini, kita dapat mengekstrak informasi penting dari halaman web secara terstruktur dan efisien.

# %%
# print(joblist.prettify())

# %% [markdown]
# #Mengambil Data dari Setiap Pekerjaan
# Setelah kita menemukan daftar pekerjaan, langkah selanjutnya adalah mengambil detail dari setiap pekerjaan yang ada pada halaman tersebut.

# %%
jobs_data = []
for artikel in joblist.find_all('article', {'class': '_32fem00 _32fem01 _1nh354w98 _1nh354w8t _1nh354w84 _1nh354w7p _1nh354wbg _1nh354wb1 _1nh354wac _1nh354w9x _1nh354wi _1nh354w6c _1nh354w5g _1qx54cib _1qx54ci9 _1qx54cia gyz43x10 gyz43x13 _1nh354w34 _1nh354w37'}):
    posisi = artikel.find('div', {'class': '_32fem00 _1nh354w5i _1nh354w54'})
    perusahaan = artikel.find(attrs={'data-automation':'jobCompany'})
    lokasi = artikel.find(attrs={'data-automation':'jobLocation'})
    gaji = artikel.find('span', {'class':'_32fem00 wo05ot2 _1nh354w50 _1nh354w0 _1nh354ws wo05ot4'})
    waktu = artikel.find(attrs={'data-automation':'jobListingDate'})
    deskripsi = artikel.find('span', {'class':'_32fem00 _1nh354w50 gyz43x0 gyz43x1 gyz43x1u gyz43x6 _1lwlriv4'})

# %% [markdown]
# **Menelusuri dan Mengekstrak Informasi Detail Pekerjaan**
#
# - find_all(): Digunakan untuk menemukan semua elemen <article> yang sesuai dengan class tertentu. Ini memungkinkan kita mengakses seluruh daftar lowongan pekerjaan yang ditampilkan pada halaman.
#
# Setelah setiap elemen artikel ditemukan, kita dapat mengekstrak berbagai informasi penting dari masing-masing lowongan, seperti:
#
# *   Posisi: Nama atau judul pekerjaan yang ditawarkan.
# *   Perusahaan: Nama perusahaan yang membuka lowongan.
# *   Lokasi: Lokasi penempatan kerja.
# *   Gaji: Informasi mengenai kisaran atau detail gaji (jika tersedia).
# *   Waktu: Kapan lowongan tersebut diunggah atau diperbarui.
# *   Deskripsi: Ringkasan singkat mengenai tanggung jawab dan kualifikasi pekerjaan.
#
# Semua informasi ini bisa diambil dengan memanfaatkan metode seperti .find() atau .text pada masing-masing elemen HTML dalam struktur hasil parsing.

# %% [markdown]
# ##Menangani Elemen yang Tidak Ditemukan
# Saat melakukan web scraping, tidak semua elemen HTML yang kita cari selalu tersedia. Oleh karena itu, penting untuk menangani kemungkinan elemen tidak ditemukan agar program tetap berjalan tanpa error.

# %%
posisi_text = posisi.get_text() if posisi else "Posisi tidak ditemukan"
perusahaan_text = perusahaan.get_text() if perusahaan else "Perusahaan tidak ditemukan"
lokasi_text = lokasi.get_text() if lokasi else "Lokasi tidak ditemukan"
gaji_text = gaji.get_text() if gaji else "Gaji tidak disebutkan"
waktu_text = waktu.get_text() if waktu else "Waktu tidak ditemukan"
deskripsi_text = deskripsi.get_text() if deskripsi else "Deskripsi tidak ditemukan"

# %% [markdown]
# Salah satu pendekatan umum adalah menggunakan operator ternary untuk memberikan nilai default jika elemen tidak ditemukan.
#
# - get_text() digunakan untuk mengambil isi teks dari suatu elemen HTML.
#
# - Jika elemen tidak tersedia (misalnya None), kita bisa memberikan nilai pengganti, seperti: "Posisi tidak ditemukan"
#
# Dengan teknik ini, proses ekstraksi data tetap berjalan mulus meskipun ada data yang hilang atau tidak lengkap pada halaman yang di-scrape.

# %% [markdown]
# ## Menyimpan Data ke List
# Setelah semua data berhasil diambil, kita menyimpan data tersebut dalam sebuah list jobs_data.

# %%
jobs_data.append({
    "Posisi": posisi_text,
    "Perusahaan": perusahaan_text,
    "Lokasi": lokasi_text,
    "Gaji": gaji_text,
    "Waktu": waktu_text,
    "Deskripsi": deskripsi_text
})

# %% [markdown]
# - append() digunakan untuk menambahkan setiap item data pekerjaan ke dalam list bernama jobs_data.
#
# Setiap data yang ditambahkan biasanya disimpan dalam bentuk dictionary, yang berisi pasangan key-value seperti posisi, perusahaan, lokasi, gaji, waktu, dan deskripsi.

# %% [markdown]
# ## *Code* lengkap pengambilan data (1 halaman web)

# %%
jobs_data = []
for artikel in joblist.find_all('article', {'class': '_32fem00 _32fem01 _1nh354w98 _1nh354w8t _1nh354w84 _1nh354w7p _1nh354wbg _1nh354wb1 _1nh354wac _1nh354w9x _1nh354wi _1nh354w6c _1nh354w5g _1qx54cib _1qx54ci9 _1qx54cia gyz43x10 gyz43x13 _1nh354w34 _1nh354w37'}):
    posisi = artikel.find('div', {'class': '_32fem00 _1nh354w5i _1nh354w54'})
    perusahaan = artikel.find(attrs={'data-automation':'jobCompany'})
    lokasi = artikel.find(attrs={'data-automation':'jobLocation'})
    gaji = artikel.find('span', {'class':'_32fem00 wo05ot2 _1nh354w50 _1nh354w0 _1nh354ws wo05ot4'})
    waktu = artikel.find(attrs={'data-automation':'jobListingDate'})
    deskripsi = artikel.find('span', {'class':'_32fem00 _1nh354w50 gyz43x0 gyz43x1 gyz43x1u gyz43x6 _1lwlriv4'})

    posisi_text = posisi.get_text() if posisi else "Posisi tidak ditemukan"
    perusahaan_text = perusahaan.get_text() if perusahaan else "Perusahaan tidak ditemukan"
    lokasi_text = lokasi.get_text() if lokasi else "Lokasi tidak ditemukan"
    gaji_text = gaji.get_text() if gaji else "Gaji tidak disebutkan"
    waktu_text = waktu.get_text() if waktu else "Waktu tidak ditemukan"
    deskripsi_text = deskripsi.get_text() if deskripsi else "Deskripsi tidak ditemukan"

    print(posisi_text)
    print(perusahaan_text)
    print(lokasi_text)
    print(gaji_text)
    print(waktu_text)
    print(deskripsi_text)
    print("==========================================")

    jobs_data.append({
        "Posisi": posisi_text,
        "Perusahaan": perusahaan_text,
        "Lokasi": lokasi_text,
        "Gaji": gaji_text,
        "Waktu": waktu_text,
        "Deskripsi": deskripsi_text
    })
# Out:
# Data Scientist
# PT Ninety Nine Dotco
# Jakarta Raya
# Gaji tidak disebutkan
# 5 hari yang lalu
# We are looking for a data scientist who is equally comfortable writing SQL queries and ML models as they are stepping into a room with stakeholders...
# ==========================================
# Junior Data Scientist
# PT Fata Organa Solusi
# Tangerang
# Rp 8.500.000 – Rp 10.500.000 per month
# 1 hari yang lalu
# Career growth opportunity in a rapidly growing company
# ==========================================
# Senior Data Scientist
# PT Kamoro Maxima Integra
# Jakarta Raya
# Gaji tidak disebutkan
# 9 hari yang lalu
# Minimum 5 years experience as Data Scientist, strong in predictive modelling, python, cloud-based ML (Azure). Willing to travel.
# ==========================================
# Data Scientist (Analytics)
# PT Solusi Transportasi Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 16 hari yang lalu
# You will use data to understand user needs and be the de-facto Voice of the Customer (users, driver-partners, merchants, agents) across GrabFin's...
# ==========================================
# Data Analyst
# Pengiklan Anonim
# Tangerang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Budaya kerja kekeluargaan
# ==========================================
# IT Data Scientist
# Pengiklan Anonim
# Jakarta Raya
# Gaji tidak disebutkan
# 10 hari yang lalu
# Mengembangkan dan mengelola dan mengelola vector database dan ML Models perusahaan dan terus mengoptimalkan akurasi dari informasi yang diberikan.
# ==========================================
# Data Analytics Specialist
# PT Gunung Raja Paksi,Tbk
# Cikarang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Job Description :Assist business operation analytics team in solving business problems and finding new business opportunities.Conduct deep research...
# ==========================================
# Data Analyst
# PT Behaestex
# Gresik
# Rp 4.000.000 – Rp 5.500.000 per month
# 5 hari yang lalu
# -
# ==========================================
# Data Analyst Manager
# Universitas Horizon Indonesia
# Karawang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Gaji bulanan, Jenjang Karir, Fasilitas makan siang
# ==========================================
# Data Scientist Specialist
# PT Richeese Kuliner Indonesia
# Bandung
# Gaji tidak disebutkan
# 19 hari yang lalu
# Create Model Development in order to provide insight and solutions,  as well as developments that will be carried out by the company
# ==========================================
# DATA ENGINEER
# PT Mitracomm Ekasarana
# Jakarta Raya
# Rp 6.000.000 – Rp 6.200.000 per month
# 3 hari yang lalu
# • Hands on experience using programming languages like Python, Scala, Java, SQL
# ==========================================
# Senior Data Scientist
# PT Ninety Nine Dotco
# Jakarta Raya
# Gaji tidak disebutkan
# 9 hari yang lalu
# We are looking for a mid/senior-level data scientist who is equally comfortable writing SQL queries and ML models as they are stepping into a room...
# ==========================================
# Data Engineer Supervisor
# PT. Cakra Radha Mustika
# Jakarta Timur
# Rp 10.000.000 – Rp 13.000.000 per month
# 4 hari yang lalu
# The role includes establishing data engineering frameworks, ensuring data security and compliance, and providing technical guidance to the team.
# ==========================================
# Data Analyst
# PT Kalowave Teknologi Indonesia
# Jakarta Barat
# Rp 5.650.000 – Rp 7.500.000 per month
# 26 hari yang lalu
# Data Analyst dibutuhkan di TikTok Shop, Jakarta Barat. Tanggung jawab: analisis data e-commerce untuk mendukung pertumbuhan toko. Full-time, segera.
# ==========================================
# Portfolio Analytics Specialist
# PT CIMB Niaga Auto Finance
# Tangerang Selatan
# Gaji tidak disebutkan
# 2 hari yang lalu
# Melakukan analisis kinerja portofolio pembiayaan dan memberikan rekomendasi berbasis data untuk mendukung pencapaian target perusahaan secara optimal.
# ==========================================
# Expert, Cloudera & Dataiku (Data Engineer)
# ASIA PULP AND PAPER
# Tangerang Selatan
# Gaji tidak disebutkan
# 8 hari yang lalu
# We are looking for Data Engineer to be part of our IT Business Insight and Analytics Team.
# ==========================================
# Data Analyst
# Katamata Group
# Jakarta Pusat
# Rp 6.000.000 – Rp 7.000.000 per month
# 12 hari yang lalu
# - Membuat analisa terkait gudang
# ==========================================
# Data Analyst
# Belah Doeren
# Bandung
# Gaji tidak disebutkan
# 10 hari yang lalu
# Bertanggung jawab untuk mengumpulkan, memproses, menganalisa dan menyajikan data untuk mendukung pengambilan keputusan strategis manajemen
# ==========================================
# Data Analyst & Compiling Leader
# PT Gunung Raja Paksi,Tbk
# Cikarang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Manage and organize office administration to ensure smooth day-to-day operations.
# ==========================================
# Data Analyst
# PT Propan Raya Industrial Coating Chemicals
# Tangerang
# Gaji tidak disebutkan
# 26 hari yang lalu
# Memberikan rekomendasi berbasis data kepada stakeholder terkait
# Berkolaborasi dengan tim lintas fungsi untuk memahami kebutuhan analitik
# ==========================================
# Senior Data Analyst (Cartography)
# PT Aplikasi Karya Anak Bangsa (GO-JEK Indonesia)
# Jakarta Raya
# Gaji tidak disebutkan
# 17 hari yang lalu
# As a Senior Data Analyst in Cartography’s team, you will be involved in working to optimize the routing platform that powers many of Gojek services...
# ==========================================
# Data Loss Prevention & Personal Data Protection Specialist
# ASIA PULP AND PAPER
# Tangerang Selatan
# Gaji tidak disebutkan
# 8 hari yang lalu
# We are currently looking for candidates with experience in Data Security and Data Loss Prevention.
# ==========================================
# Data Intelligence Specialist
# PT BPR Kredit Mandiri Indonesia
# Tangerang Selatan
# Gaji tidak disebutkan
# 6 hari yang lalu
# Jenjang Karir
# ==========================================
# Data Analyst
# Pengiklan Anonim
# Jakarta Selatan
# Gaji tidak disebutkan
# 9 hari yang lalu
# Data Analysis, Trade Sales/ marketing, sales performance, dashboards and sales performance
# ==========================================
# AI Engineer
# Deep Symbolics Indonesia
# Jakarta Raya
# Rp 10.000.000 – Rp 15.000.000 per month
# 7 hari yang lalu
# Build next-gen AI for businesses, work with LLMs & cloud, and shape intelligent automation in enterprise systems. Hybrid in Indonesia! Join us!
# ==========================================
# Data Analyst
# Indesso
# Cileungsi
# Gaji tidak disebutkan
# 11 hari yang lalu
# We are seeking an experienced & dynamic professional with a passion in data analysis and reporting to manage resources in one of business unit.
# ==========================================
# Jr. Data Analyst
# PT Jasa Angkasa Semesta
# Tangerang
# Gaji tidak disebutkan
# 13 hari yang lalu
# Positive Company Culture
# ==========================================
# Senior Data Analytics
# PT Adecco Personnel Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 27 hari yang lalu
# We are looking for a seasoned Senior Data Analyst or Data Scientist with proven experience in the lending domain
# ==========================================
# Data Analyst Associate
# PT Solusi Transportasi Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 12 hari yang lalu
# As a Data Analyst, Finance Product & Data Integration at Grab, you will consolidate data from various sources to provide a unified view for finance...
# ==========================================
# Senior Data Scientist
# GoTo Group
# Jakarta Raya
# Gaji tidak disebutkan
# 1 hari yang lalu
# GoPay Data Science team builds critical ML components/models which go into the engineering systems which make GoPay a safe, trusted and fun way to...
# ==========================================
# Customer Solutions Consultant, Data Analytics, Google Cloud
# Google
# Jakarta Raya
# Gaji tidak disebutkan
# 18 hari yang lalu
# Room and opportunities to grow — on your own and with your teammates.
# ==========================================
# DATA ANALYST
# PT Pesta Pora Abadi
# Malang
# Gaji tidak disebutkan
# 19 hari yang lalu
# HR Data Analyst
# ==========================================

# %% [markdown]
# #Menyimpan Data dari Satu Halaman ke CSV
# Setelah data dari satu halaman terkumpul, kita bisa menyimpan hasilnya ke dalam bentuk file CSV.

# %%
df_jobs = pd.DataFrame(jobs_data)
#df_jobs.to_csv('Data_Job_Listings.csv', index=False)

# %% [markdown]
# - **pd.DataFrame()** digunakan untuk mengonversi list jobs_data (yang berisi kumpulan dictionary data pekerjaan) menjadi objek DataFrame dari Pandas.
# DataFrame ini memudahkan kita dalam melakukan analisis, pemfilteran, visualisasi, maupun ekspor data ke format lain.
# - **to_csv()** berfungsi untuk menyimpan DataFrame ke dalam file CSV, sehingga data dapat digunakan kembali di luar Python, seperti di Excel atau aplikasi pengolah data lainnya.

# %%
df_jobs.head()
# Out:
#                        Posisi                        Perusahaan        Lokasi  \
# 0              Data Scientist              PT Ninety Nine Dotco  Jakarta Raya
# 1       Junior Data Scientist             PT Fata Organa Solusi     Tangerang
# 2       Senior Data Scientist          PT Kamoro Maxima Integra  Jakarta Raya
# 3  Data Scientist (Analytics)  PT Solusi Transportasi Indonesia  Jakarta Raya
# 4                Data Analyst                  Pengiklan Anonim     Tangerang
#
#                                      Gaji              Waktu  \
# 0                   Gaji tidak disebutkan   5 hari yang lalu
# 1  Rp 8.500.000 – Rp 10.500.000 per month   1 hari yang lalu
# 2                   Gaji tidak disebutkan   9 hari yang lalu
# 3                   Gaji tidak disebutkan  16 hari yang lalu
# 4                   Gaji tidak disebutkan   5 hari yang lalu
#
#                                            Deskripsi
# 0  We are looking for a data scientist who is equ...
# 1  Career growth opportunity in a rapidly growing...
# 2  Minimum 5 years experience as Data Scientist, ...
# 3  You will use data to understand user needs and...
# 4                          Budaya kerja kekeluargaan

# %% [markdown]
# #Scrapping Multi Halaman (Halaman 1-4)
# Setelah berhasil scraping satu halaman, kita bisa memperluas scraping ke beberapa halaman sekaligus. Kita bisa menggunakan loop untuk mengambil data dari halaman 1 hingga halaman tertentu. Pada kasus ini karena pada website Jobstreet hanya tersedia hingga halaman ke 4, maka range halaman yang akan di scrapping adalah 5 sebagai batas atasnya.

# %%
jobs_data = []

for i in range(1,5):
  url = f'https://id.jobstreet.com/id/Data-Scientist-jobs/full-time?daterange=31&page={i}&salaryrange=2000000-&salarytype=monthly&workarrangement=1%2C3%2C2'

  headers = {
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.6668.90"
    }

  s = requests.session()
  s.headers.update(headers)

  try:
      page = s.get(url)
      soup = BeautifulSoup(page.text, "lxml")
      joblist = soup.find('div', class_='_32fem00 _1nh354wo')

      for artikel in joblist.find_all('article', {'class': '_32fem00 _32fem01 _1nh354w98 _1nh354w8t _1nh354w84 _1nh354w7p _1nh354wbg _1nh354wb1 _1nh354wac _1nh354w9x _1nh354wi _1nh354w6c _1nh354w5g _1qx54cib _1qx54ci9 _1qx54cia gyz43x10 gyz43x13 _1nh354w34 _1nh354w37'}):
          posisi = artikel.find('div', {'class': '_32fem00 _1nh354w5i _1nh354w54'})
          perusahaan = artikel.find(attrs={'data-automation':'jobCompany'})
          lokasi = artikel.find(attrs={'data-automation':'jobLocation'})
          gaji = artikel.find('span', {'class':'_32fem00 wo05ot2 _1nh354w50 _1nh354w0 _1nh354ws wo05ot4'})
          waktu = artikel.find(attrs={'data-automation':'jobListingDate'})
          deskripsi = artikel.find('span', {'class':'_32fem00 _1nh354w50 gyz43x0 gyz43x1 gyz43x1u gyz43x6 _1lwlriv4'})

          posisi_text = posisi.get_text() if posisi else "Posisi tidak ditemukan"
          perusahaan_text = perusahaan.get_text() if perusahaan else "Perusahaan tidak disebutkan"
          lokasi_text = lokasi.get_text() if lokasi else "Lokasi tidak ditemukan"
          gaji_text = gaji.get_text() if gaji else "Gaji tidak disebutkan"
          waktu_text = waktu.get_text() if waktu else "Waktu tidak ditemukan"
          deskripsi_text = deskripsi.get_text() if deskripsi else "Deskripsi tidak ditemukan"

          jobs_data.append({
            "Posisi": posisi_text,
            "Perusahaan": perusahaan_text,
            "Lokasi": lokasi_text,
            "Gaji": gaji_text,
            "Waktu": waktu_text,
            "Deskripsi": deskripsi_text
          })

          print(posisi_text)
          print(perusahaan_text)
          print(lokasi_text)
          print(gaji_text)
          print(waktu_text)
          print(deskripsi_text)
          print("===============================")
  except requests.exceptions.RequestException as e:
      print(f"Error: {e}")
# Out:
# Data Scientist
# PT Ninety Nine Dotco
# Jakarta Raya
# Gaji tidak disebutkan
# 5 hari yang lalu
# We are looking for a data scientist who is equally comfortable writing SQL queries and ML models as they are stepping into a room with stakeholders...
# ===============================
# Junior Data Scientist
# PT Fata Organa Solusi
# Tangerang
# Rp 8.500.000 – Rp 10.500.000 per month
# 1 hari yang lalu
# Career growth opportunity in a rapidly growing company
# ===============================
# Senior Data Scientist
# PT Kamoro Maxima Integra
# Jakarta Raya
# Gaji tidak disebutkan
# 9 hari yang lalu
# Minimum 5 years experience as Data Scientist, strong in predictive modelling, python, cloud-based ML (Azure). Willing to travel.
# ===============================
# Data Scientist (Analytics)
# PT Solusi Transportasi Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 16 hari yang lalu
# You will use data to understand user needs and be the de-facto Voice of the Customer (users, driver-partners, merchants, agents) across GrabFin's...
# ===============================
# Data Analyst
# Pengiklan Anonim
# Tangerang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Budaya kerja kekeluargaan
# ===============================
# IT Data Scientist
# Pengiklan Anonim
# Jakarta Raya
# Gaji tidak disebutkan
# 10 hari yang lalu
# Mengembangkan dan mengelola dan mengelola vector database dan ML Models perusahaan dan terus mengoptimalkan akurasi dari informasi yang diberikan.
# ===============================
# Data Analytics Specialist
# PT Gunung Raja Paksi,Tbk
# Cikarang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Job Description :Assist business operation analytics team in solving business problems and finding new business opportunities.Conduct deep research...
# ===============================
# Data Analyst
# PT Behaestex
# Gresik
# Rp 4.000.000 – Rp 5.500.000 per month
# 5 hari yang lalu
# -
# ===============================
# Data Analyst Manager
# Universitas Horizon Indonesia
# Karawang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Gaji bulanan, Jenjang Karir, Fasilitas makan siang
# ===============================
# Data Scientist Specialist
# PT Richeese Kuliner Indonesia
# Bandung
# Gaji tidak disebutkan
# 19 hari yang lalu
# Create Model Development in order to provide insight and solutions,  as well as developments that will be carried out by the company
# ===============================
# DATA ENGINEER
# PT Mitracomm Ekasarana
# Jakarta Raya
# Rp 6.000.000 – Rp 6.200.000 per month
# 3 hari yang lalu
# • Hands on experience using programming languages like Python, Scala, Java, SQL
# ===============================
# Senior Data Scientist
# PT Ninety Nine Dotco
# Jakarta Raya
# Gaji tidak disebutkan
# 9 hari yang lalu
# We are looking for a mid/senior-level data scientist who is equally comfortable writing SQL queries and ML models as they are stepping into a room...
# ===============================
# Data Engineer Supervisor
# PT. Cakra Radha Mustika
# Jakarta Timur
# Rp 10.000.000 – Rp 13.000.000 per month
# 4 hari yang lalu
# The role includes establishing data engineering frameworks, ensuring data security and compliance, and providing technical guidance to the team.
# ===============================
# Data Analyst
# PT Kalowave Teknologi Indonesia
# Jakarta Barat
# Rp 5.650.000 – Rp 7.500.000 per month
# 26 hari yang lalu
# Data Analyst dibutuhkan di TikTok Shop, Jakarta Barat. Tanggung jawab: analisis data e-commerce untuk mendukung pertumbuhan toko. Full-time, segera.
# ===============================
# Portfolio Analytics Specialist
# PT CIMB Niaga Auto Finance
# Tangerang Selatan
# Gaji tidak disebutkan
# 2 hari yang lalu
# Melakukan analisis kinerja portofolio pembiayaan dan memberikan rekomendasi berbasis data untuk mendukung pencapaian target perusahaan secara optimal.
# ===============================
# Expert, Cloudera & Dataiku (Data Engineer)
# ASIA PULP AND PAPER
# Tangerang Selatan
# Gaji tidak disebutkan
# 8 hari yang lalu
# We are looking for Data Engineer to be part of our IT Business Insight and Analytics Team.
# ===============================
# Data Analyst
# Katamata Group
# Jakarta Pusat
# Rp 6.000.000 – Rp 7.000.000 per month
# 12 hari yang lalu
# - Membuat analisa terkait gudang
# ===============================
# Data Analyst
# Belah Doeren
# Bandung
# Gaji tidak disebutkan
# 10 hari yang lalu
# Bertanggung jawab untuk mengumpulkan, memproses, menganalisa dan menyajikan data untuk mendukung pengambilan keputusan strategis manajemen
# ===============================
# Data Analyst & Compiling Leader
# PT Gunung Raja Paksi,Tbk
# Cikarang
# Gaji tidak disebutkan
# 5 hari yang lalu
# Manage and organize office administration to ensure smooth day-to-day operations.
# ===============================
# Data Analyst
# PT Propan Raya Industrial Coating Chemicals
# Tangerang
# Gaji tidak disebutkan
# 26 hari yang lalu
# Memberikan rekomendasi berbasis data kepada stakeholder terkait
# Berkolaborasi dengan tim lintas fungsi untuk memahami kebutuhan analitik
# ===============================
# Senior Data Analyst (Cartography)
# PT Aplikasi Karya Anak Bangsa (GO-JEK Indonesia)
# Jakarta Raya
# Gaji tidak disebutkan
# 17 hari yang lalu
# As a Senior Data Analyst in Cartography’s team, you will be involved in working to optimize the routing platform that powers many of Gojek services...
# ===============================
# Data Loss Prevention & Personal Data Protection Specialist
# ASIA PULP AND PAPER
# Tangerang Selatan
# Gaji tidak disebutkan
# 8 hari yang lalu
# We are currently looking for candidates with experience in Data Security and Data Loss Prevention.
# ===============================
# Data Intelligence Specialist
# PT BPR Kredit Mandiri Indonesia
# Tangerang Selatan
# Gaji tidak disebutkan
# 6 hari yang lalu
# Jenjang Karir
# ===============================
# Data Analyst
# Pengiklan Anonim
# Jakarta Selatan
# Gaji tidak disebutkan
# 9 hari yang lalu
# Data Analysis, Trade Sales/ marketing, sales performance, dashboards and sales performance
# ===============================
# AI Engineer
# Deep Symbolics Indonesia
# Jakarta Raya
# Rp 10.000.000 – Rp 15.000.000 per month
# 7 hari yang lalu
# Build next-gen AI for businesses, work with LLMs & cloud, and shape intelligent automation in enterprise systems. Hybrid in Indonesia! Join us!
# ===============================
# Data Analyst
# Indesso
# Cileungsi
# Gaji tidak disebutkan
# 11 hari yang lalu
# We are seeking an experienced & dynamic professional with a passion in data analysis and reporting to manage resources in one of business unit.
# ===============================
# Jr. Data Analyst
# PT Jasa Angkasa Semesta
# Tangerang
# Gaji tidak disebutkan
# 13 hari yang lalu
# Positive Company Culture
# ===============================
# Senior Data Analytics
# PT Adecco Personnel Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 27 hari yang lalu
# We are looking for a seasoned Senior Data Analyst or Data Scientist with proven experience in the lending domain
# ===============================
# Data Analyst Associate
# PT Solusi Transportasi Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 12 hari yang lalu
# As a Data Analyst, Finance Product & Data Integration at Grab, you will consolidate data from various sources to provide a unified view for finance...
# ===============================
# Senior Data Scientist
# GoTo Group
# Jakarta Raya
# Gaji tidak disebutkan
# 1 hari yang lalu
# GoPay Data Science team builds critical ML components/models which go into the engineering systems which make GoPay a safe, trusted and fun way to...
# ===============================
# Customer Solutions Consultant, Data Analytics, Google Cloud
# Google
# Jakarta Raya
# Gaji tidak disebutkan
# 18 hari yang lalu
# Room and opportunities to grow — on your own and with your teammates.
# ===============================
# DATA ANALYST
# PT Pesta Pora Abadi
# Malang
# Gaji tidak disebutkan
# 19 hari yang lalu
# HR Data Analyst
# ===============================
# Artificial Intelligence
# PT Warna Warni Media
# Surabaya
# Gaji tidak disebutkan
# 11 hari yang lalu
# Bergabunglah dengan perusahaan kami untuk mengembangkan Artificial Intelligence yang terbaik.
# ===============================
# Manufacturing Data Analyst
# PT Eka Bogainti
# Ciracas
# Gaji tidak disebutkan
# 10 hari yang lalu
# Exciting data-driven role reporting directly to CEO at leading Jakarta consultancy. Competitive salary, excellent benefits.
# ===============================
# Head of Data
# PT Ninety Nine Dotco
# Jakarta Raya
# Gaji tidak disebutkan
# 1 hari yang lalu
# At 99 Group, we're on a mission to revolutionise the real estate industry by seamlessly integrating cutting-edge technology and innovation. We are...
# ===============================
# Dosen Prodi Data Science (UBM Kampus Serpong)
# Universitas Bunda Mulia (Yayasan Pendidikan Bunda Mulia )
# Tangerang
# Gaji tidak disebutkan
# 19 hari yang lalu
# Dosen Prodi Data Science dengan kompetensi dalam bidang Big Data, Machine Learning, Python, Data Mining. Berpengalaman sebagai dosen maupun praktisi.
# ===============================
# Data Analyst Specialist
# PT Richeese Kuliner Indonesia
# Bandung
# Gaji tidak disebutkan
# 11 hari yang lalu
# Job Description:  Doing data Selection &amp; Preparation and Data Analysis using different data Coordination with data providers Collect and ensure...
# ===============================
# Careline Data Analyst
# PT Coway International Indonesia
# Jakarta Selatan
# Gaji tidak disebutkan
# 8 hari yang lalu
# Strategic Planner to support the Careline team by forecasting workload, developing dashboards, and maintaining high operational readiness.
# ===============================
# Data Engineer
# PT Data Labs Analytics
# Jakarta Pusat
# Gaji tidak disebutkan
# 19 hari yang lalu
# Collaborate with cross-functional teams to design & implement data solutions. Strong understanding of business requirements.
# ===============================
# Data Analyst – Pricing Staff
# PT Global Jet Cargo (J&T Cargo)
# Jakarta Utara
# Gaji tidak disebutkan
# 12 hari yang lalu
# Analyze & maintain data, review pricing, track costs, and support strategy with dashboards for business performance.
# ===============================
# Data Engineer (Officer)
# Dexa Group
# Tangerang Selatan
# Gaji tidak disebutkan
# 20 hari yang lalu
# To build and organize a data pipeline (ETL/ELT) procedure for usage in a data warehouse environment
# ===============================
# IT Data Engineer
# PT ABC KOGEN DAIRY
# Jakarta Selatan
# Gaji tidak disebutkan
# 11 hari yang lalu
# Build and maintain data pipelines, ensure data quality, and support analytics through visualization and IT team collaboration.
# ===============================
# Data Support (Jatim)
# Pengiklan Anonim
# Surabaya
# Gaji tidak disebutkan
# 16 hari yang lalu
# Pekerjaan ini banyak melakukan support terhadap project yang berjalan, mengecek kesesuaikan flow dan memberikan solusi awal pada permasalahan yang ada
# ===============================
# Cloud AI/ML Engineer
# PT. Berca Hardayaperkasa
# Jakarta Pusat
# Gaji tidak disebutkan
# 29 hari yang lalu
# Design, build, and optimize machine learning models for real-world applications
# ===============================
# Analyst, Data Engineer
# PT Bank DBS Indonesia
# Indonesia
# Gaji tidak disebutkan
# 25 hari yang lalu
# Ensure user requirements on data needs are captured
# Develop scripts/tools to support data requirements and ingestion from BU/SU
# Maintain good...
# ===============================
# Data Analyst
# PT Mata Pelangi Chemindo
# Jakarta Barat
# Gaji tidak disebutkan
# 18 hari yang lalu
# We are looking to hire a Data Analyst to join us.
# ===============================
# Logistic Data Analyst
# PT Zoomlion Indonesia Heavy Industry
# Jakarta Utara
# Gaji tidak disebutkan
# 12 hari yang lalu
# Supporting logistics team regarding data and system
# ===============================
# Senior AI Engineer
# PT SMART,Tbk
# Jakarta Selatan
# Gaji tidak disebutkan
# 23 hari yang lalu
# Having a strong technical foundation in AI/ML, computer vision, and cutting-edge AI techniques
# ===============================
# Macroeconomist
# TUNTUN SEKURITAS INDONESIA
# Jakarta Utara
# Gaji tidak disebutkan
# 5 hari yang lalu
# Stata
# ===============================
# Data Analyst
# WINOD RITEL INDONESIA
# Karang Tengah
# Rp 4.500.000 – Rp 5.500.000 per month
# 26 hari yang lalu
# Data Analyst
# ===============================
# Staff Data Analyst (Mandarin Speaker)
# PT Global Jet Express
# Surakarta
# Gaji tidak disebutkan
# 15 hari yang lalu
# Menentukan kebutuhan data dan mengembangkan strategi analisis
# ===============================
# Data Analyst
# Altius Hospital
# Jakarta Barat
# Gaji tidak disebutkan
# 25 hari yang lalu
# Develop, implement, and maintain leading-edge analytical systems, taking complex problems and building simple frameworks
# ===============================
# AI Developer Specialist
# Karunia Prima Nastari (KPN CORP.)
# Jakarta Selatan
# Gaji tidak disebutkan
# 18 hari yang lalu
# AI Developer Specialist has the responsibility to design, build, and implement artificial intelligence models and systems
# ===============================
# Data & AI Architect
# PT Mitra Solusi Telematika
# Jakarta Selatan
# Gaji tidak disebutkan
# 25 hari yang lalu
# Reputable company
# ===============================
# Data Speacialist (Mandarin Mandatory)
# Horizon Construction Development
# Jakarta Raya
# Gaji tidak disebutkan
# 4 hari yang lalu
# Urgently Hiring
# ===============================
# Data ANALYSIS and ENTRY
# OSSEH INDONESIA
# Purwosari
# Rp 4.000.000 – Rp 4.500.000 per month
# 13 hari yang lalu
# Data Analytics Certification
# ===============================
# Senior Data Analyst
# Siloam Hospitals Group (Tbk)
# Karawaci
# Gaji tidak disebutkan
# 17 hari yang lalu
# Lead data-driven initiatives at Indonesia's top healthcare provider. Competitive salary, benefits, and growth opportunities.
# ===============================
# Technical Consultant Analyst
# PT. Metrodata Electronics, Tbk
# Jakarta Raya
# Gaji tidak disebutkan
# 1 hari yang lalu
# Ikut serta mengevaluasi, mengidentifikasi, serta memberikan rekomendasi, dalam hal memberikan solusi dan konsultasi yang sesuai dengan kebutuhan...
# ===============================
# Senior Officer, Data Chapter
# PT Bank DBS Indonesia
# Indonesia
# Gaji tidak disebutkan
# 23 hari yang lalu
# Interest in Analysis\: Enjoying the process of analysis with enthusiasm and having the desire to continuously learn and better understand...
# ===============================
# Data Annotator
# PT STAR Indonesia
# Yogyakarta
# Gaji tidak disebutkan
# 16 hari yang lalu
# We are looking for a Data Annotator with strong attention to detail and a solid understanding of local language nuances.
# ===============================
# Lead Data Scientist - Big Data and Modelling
# Cermati Fintech Group
# Jakarta Raya
# Gaji tidak disebutkan
# 5 hari yang lalu
# Indodana Fintech is an OJK-licensed financial technology company that operates a credit marketplace for peer-to-peer loans. Our mission is to...
# ===============================
# Lead Data Scientist
# Coca-Cola Europacific Partners Indonesia
# Indonesia
# Gaji tidak disebutkan
# 30+ hari yang lalu
# The Lead Data Scientist will deliver AI explorations identified via the AI Incubator process across the APS region. This hands-on role requires a...
# ===============================
# AI Engineer
# VLink Inc
# Kemayoran
# Gaji tidak disebutkan
# 11 jam yang lalu
# We are seeking a highly skilled Senior AI Engineer to design, develop, and deploy advanced AI and machine learning models. The ideal candidate will...
# ===============================
# IT & AI Automation
# Akasha Yoga Academy
# Ubud
# Gaji tidak disebutkan
# 30+ hari yang lalu
# Work with cutting-edge AI tools to automate real business processes.
# ===============================
# Agent Prompter Layanan I2P SDA
# Infomedia
# Jawa Barat
# Gaji tidak disebutkan
# 5 jam yang lalu
# 1. Diutamakan lulusan Teknik Informatika/Ilmu computer dan sejenis nya yang memiliki background Pendidikan dan pekerjaan di Bidang AI 2. Minimal...
# ===============================
# Alibaba Cloud-Product Solution Architect (Big Data & AI)-Jakarta, Indonesia
# Alibaba Cloud
# Jakarta Raya
# Gaji tidak disebutkan
# 29 hari yang lalu
# 1. Lead the development and standardization of big data and AI product solutions, responsible for the full process solution support from pre-sale...
# ===============================
# Senior Machine Learning Engineer
# PT Appfuxion Consulting
# Kecamatan Tangerang
# Gaji tidak disebutkan
# 18 hari yang lalu
# This is a full-time on-site role for a Senior Machine Learning Engineer located in Tangerang. As a Senior Machine Learning Engineer, you will be...
# ===============================
# Software Engineer - Devops
# GoTo Group
# Jakarta Raya
# Gaji tidak disebutkan
# 1 hari yang lalu
# As Nasi Goreng is to the people of Indonesia, engineers are to GoTo Financial: sustaining and nourishing the longevity of our business from the...
# ===============================
# Data Scientist
# PT Cerdas Digital Nusantara
# Jakarta Raya
# Gaji tidak disebutkan
# 2 hari yang lalu
# Data scientist roles and responsibilities include:
# Data mining or extracting usable data from valuable data sources
# Using machine learning toolsto...
# ===============================
# Data Scientist
# SUN LIFE INDONESIA
# Kebayoran Lama
# Gaji tidak disebutkan
# 2 hari yang lalu
# We are seeking a Data Scientist to develop data-driven solutions through statistical analysis, predictive modeling, and machine learning. The role...
# ===============================
# Data Analyst/Data Scientist (Project-Based)
# Soedarpo Informatika
# Jakarta Raya
# Rp 8.500.000 – Rp 11.500.000 per month
# 3 hari yang lalu
# THR
# ===============================
# Data Analyst
# PT Mega Adhitama Perkasa
# Tangerang
# Gaji tidak disebutkan
# 1 hari yang lalu
# Mengembangkan laporan, visualisasi data
# ===============================
# Machine Learning Engineer
# PT Data Labs Analytics
# Jakarta Pusat
# Gaji tidak disebutkan
# 3 hari yang lalu
# Machine Learning Engineer needed to design, build, and optimize scalable ML models and data infrastructure.
# ===============================
# Data Scientist (Analytics)
# Data Analytics
# Jakarta Raya
# Gaji tidak disebutkan
# 16 hari yang lalu
# You will use data to understand user needs and be the de-facto Voice of the Customer (users, driver-partners, merchants, agents) across GrabFin's...
# ===============================
# Data Visualization Analyst
# PT. Global Asta Nusantara
# Sidoarjo
# Gaji tidak disebutkan
# 1 hari yang lalu
# menganalisis data, membuat laporan dengan visualisasi data dan dashboard interaktif
# ===============================
# Senior Data Science
# PT GTech Digital Asia
# Kemayoran
# Gaji tidak disebutkan
# 4 hari yang lalu
# Bachelor’s or Master’s degree in Data Science, Statistics, Computer Science, Mathematics, or a related field. Proven experience (2-5 years) as a...
# ===============================
# Data Engineer
# PT Yayasan utama kasih
# Kemayoran
# Gaji tidak disebutkan
# 1 hari yang lalu
# "Skill Requirements:1. System Requirement Analysis (related Data ingestion, data staging, data cleansing, data mart)2. Create Job workflow /ETL in...
# ===============================
# Data Scientist, Business Intelligence
# Shopee Internasional Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 23 hari yang lalu
# The Business Intelligence and Data Analytics team plays a critical role in conducting close-loop data-driven business iterations. As business...
# ===============================
# Data Engineer
# PT. Sukses Corp International
# Jakarta Pusat
# Gaji tidak disebutkan
# 4 hari yang lalu
# Design, build, and maintain scalable and efficient data pipelines to collect, process, and store data from various sources
# ===============================
# NBUW Data Analytics & Reporting
# PT AIA Financial
# Jakarta Raya
# Gaji tidak disebutkan
# 1 hari yang lalu
# You must provide all requested information, including Personal Data, to be considered for this career opportunity. Failure to provide such...
# ===============================
# Data Engineering
# PT Global Unggul Mandiri (Paxel)
# Jakarta Raya
# Gaji tidak disebutkan
# 3 hari yang lalu
# Join Paxel as a Data Engineer to build secure, automated data pipelines and deliver high-quality datasets that power smarter business decisions.
# ===============================
# Data Analyst - Jakarta Barat
# PT Lippo Malls Indonesia
# Jakarta Barat
# Gaji tidak disebutkan
# 1 hari yang lalu
# Perform data analysis, data preparation and cleaning, also support segmentation and methodology development.
# ===============================
# Data Analyst - L1
# Proxima Consulting Indonesia
# Jakarta Raya
# Rp 6.000.000 – Rp 8.000.000 per month
# 2 hari yang lalu
# You will be responsible for ensuring data completeness and integrity, enriching customer-supplied information, and maintaining high data quality
# ===============================
# Data Analyst
# Yayasan Bina Nusantara
# Jakarta Barat
# Gaji tidak disebutkan
# 3 hari yang lalu
# Job Descriptions: Support daily data request from stakeholder Analyze user requirement need in data and provide accurate report and data Ensure the...
# ===============================
# Data Analyst Support
# STATS ME
# Mojokerto
# Gaji tidak disebutkan
# 8 hari yang lalu
# 1. Usia 21-27 Tahun2. Pria/Wanita3. Pendidikan Terakhir S1 Statistik, Matematika, Ekonomi, atau bidang terkait.4. Pengalaman kerja di bidang...
# ===============================
# Associate 2 - Assurance - Data Analytics - Talent Pool FY26
# KAP Rintis, Jumadi, Rianto & Rekan
# Jakarta Raya
# Gaji tidak disebutkan
# 3 hari yang lalu
# Those in data, analytics and technology solutions at PwC will assist clients in developing solutions that help build trust, drive improvement, and...
# ===============================
# Data Engineer
# PT Simian Technologies
# Jakarta Pusat
# Gaji tidak disebutkan
# 17 hari yang lalu
# Looking for energetic people passionate about technology and building great businesses.What you do: Analyzing raw data, Developing and Maintaining...
# ===============================
# Data Engineer (Azure Data Factory)
# PT Kamoro Maxima Integra
# Jakarta Selatan
# Gaji tidak disebutkan
# 9 hari yang lalu
# Developing and managing business intelligence solutions for the organization. Develop and execute database queries and conduct analyses.
# ===============================
# Data Analyst
# PT. PCU Indonesia
# Jakarta Selatan
# Gaji tidak disebutkan
# 11 hari yang lalu
# Gain insights and influence strategy; be the driving force behind smarter business decisions!
# ===============================
# Data Analyst
# CV SEMBILAN NAGA
# Bandar Lampung
# Rp 3.000.000 – Rp 4.000.000 per month
# 24 hari yang lalu
# data analys
# ===============================
# Data Analyst
# PT Berill Jaya Sejahtera
# Jawa Tengah
# Gaji tidak disebutkan
# 17 hari yang lalu
# Kami mencari kandidat yang memiliki kemampuan logika, analitis dan pemecahan masalah yang kuat
# ===============================
# AI Engineer (Artificial Intelligence)
# PT. Garena Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 10 hari yang lalu
# Maintain and improve existing AI and automation tools to ensure smooth daily operations
# Design, develop, and deploy new AI and automation solutions...
# ===============================
# Artificial Intelligence Engineer
# PT Macbramindo Harum Abadi
# Tangerang Selatan
# Rp 7.000.000 – Rp 10.000.000 per month
# 26 hari yang lalu
# AI Engineer bertanggung jawab untuk membangun, melatih, dan menerapkan model kecerdasan buatan (AI) serta integrasi ke dalam sistem produksi
# ===============================
# Data Analyst
# DVI Solution
# Jakarta Raya
# Gaji tidak disebutkan
# 10 hari yang lalu
# We are looking for a highly motivated and detail-oriented Data Analyst to join our growing team in Jakarta. The ideal candidate is analytical,...
# ===============================
# Data Analyst
# Indofood Group
# Pulo Gadung
# Gaji tidak disebutkan
# 15 hari yang lalu
# Mahir dalam Microsoft Office (Excel, PowerPoint, Word), visualisasi data, dan reporting tools
# Berpengalaman pada pengumpulan, analisa, pemodelan,...
# ===============================
# Core Data Architect
# PT AIA Financial
# Jakarta Raya
# Gaji tidak disebutkan
# 9 hari yang lalu
# You must provide all requested information, including Personal Data, to be considered for this career opportunity. Failure to provide such...
# ===============================
# Data Analyst
# PT. Global Asta Nusantara
# Sidoarjo
# Gaji tidak disebutkan
# 26 hari yang lalu
# Wajib memiliki sertifikasi Ms. Excel (Wajib dilampirkan)
# ===============================
# Data Analyst Associate
# Finance
# Jakarta Raya
# Gaji tidak disebutkan
# 12 hari yang lalu
# As a Data Analyst, Finance Product & Data Integration at Grab, you will consolidate data from various sources to provide a unified view for finance...
# ===============================
# SPV DATA ANALYST
# ROXY GROUP
# Jakarta Pusat
# Gaji tidak disebutkan
# 19 hari yang lalu
# SPV DATA ANALYST
# Bertanggung jawab untuk melakukan riset data dan membuat hasil analisis, dibutuhkan keterampilan untuk mengolah data secara akurat
# ===============================
# Data Governance Consultant
# PT Cybertrend Intrabuana
# Pasar Minggu
# Gaji tidak disebutkan
# 22 hari yang lalu
# At PT Cybertrend Intrabuana we are committed to harnessing the power of data to drive business success. We are seeking a talented and motivated...
# ===============================
# Data Operations Analyst
# Tripledot Studios
# Jakarta Raya
# Gaji tidak disebutkan
# 16 hari yang lalu
# As a hands-on technical role within the central Marketing Analytics team, you will collaborate across 12 gaming studios and multiple data functions...
# ===============================
# AI & Data Management Consultant
# NTT Communications
# Kebayoran Lama
# Gaji tidak disebutkan
# 24 hari yang lalu
# Manage the end-to-end delivery of AI projects, ensuring they meet client requirements and timelines.
# Coordinate with cross-functional teams to...
# ===============================
# Data Engineer (Data Warehouse), Business Intelligence
# Shopee Internasional Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 23 hari yang lalu
# The Business Intelligence and Data Analytics team plays a critical role in conducting close-loop data-driven business iterations. As business...
# ===============================
# Data & Application Operation Center
# PT Jaya Teknik Indonesia
# Jakarta Raya
# Gaji tidak disebutkan
# 25 hari yang lalu
# Pengalaman pekerjaan bidang IT selama minimal 7 (tujuh) tahun
# ===============================
# Product Head
# PT Cybertrend Intrabuana
# Pasar Minggu
# Gaji tidak disebutkan
# 22 hari yang lalu
# CYBERTREND, as one of key player Data Science and AI company in Indonesia. Being a part of Cybertrend Team (SmartCyber) means being a part of a...
# ===============================
# Product Innovation Excellence Head
# PT Cybertrend Intrabuana
# Pasar Minggu
# Gaji tidak disebutkan
# 22 hari yang lalu
# At CYBERTREND, we believe that every company can unlock their full execution capacity – and for that we need you as a PRODUCT INNOVATION EXCELLENCE...
# ===============================
# Senior Technology Architect
# Finns Beach Club
# Badung
# Gaji tidak disebutkan
# 6 hari yang lalu
# FINNS World's Best Beach Club is more than a beach club — it's a destination for vibrant energy and thrilling entertainment.
# ===============================
# Data Analyst - Sales
# Kredivo Group
# Indonesia
# Gaji tidak disebutkan
# 13 hari yang lalu
# Kredivo is looking for an experienced Data Analyst to support analytics needs for the Business Development function. This role is responsible for...
# ===============================

# %%
# Tampilkan hasil
df_jobs_full = pd.DataFrame(jobs_data)
df_jobs_full.head()
# Out:
#                        Posisi                        Perusahaan        Lokasi  \
# 0              Data Scientist              PT Ninety Nine Dotco  Jakarta Raya
# 1       Junior Data Scientist             PT Fata Organa Solusi     Tangerang
# 2       Senior Data Scientist          PT Kamoro Maxima Integra  Jakarta Raya
# 3  Data Scientist (Analytics)  PT Solusi Transportasi Indonesia  Jakarta Raya
# 4                Data Analyst                  Pengiklan Anonim     Tangerang
#
#                                      Gaji              Waktu  \
# 0                   Gaji tidak disebutkan   5 hari yang lalu
# 1  Rp 8.500.000 – Rp 10.500.000 per month   1 hari yang lalu
# 2                   Gaji tidak disebutkan   9 hari yang lalu
# 3                   Gaji tidak disebutkan  16 hari yang lalu
# 4                   Gaji tidak disebutkan   5 hari yang lalu
#
#                                            Deskripsi
# 0  We are looking for a data scientist who is equ...
# 1  Career growth opportunity in a rapidly growing...
# 2  Minimum 5 years experience as Data Scientist, ...
# 3  You will use data to understand user needs and...
# 4                          Budaya kerja kekeluargaan

# %%
# Menyimpan file full
df_jobs_full.to_csv('Full_Data_Job_Listings.csv', index=False)

# %%
# Melihat dimensi data
df_jobs_full.shape
# Out:
# (108, 6)

# %% [markdown]
# # **2. DATA PREPOCESSING**

# %% [markdown]
# ## Normalisasi (Lowercase & Hapus Karakter Khusus)

# %% [markdown]
# Normalisasi digunakan agar format teks seragam (huruf kecil semua dan tanpa simbol).

# %%
import re

# %%
# Mendefinisikan kembali dataset yang telah diperoleh sebelumnya agar lebih mudah dieksekusi
df = df_jobs_full.copy()
df
# Out:
#                                   Posisi                        Perusahaan  \
# 0                         Data Scientist              PT Ninety Nine Dotco
# 1                  Junior Data Scientist             PT Fata Organa Solusi
# 2                  Senior Data Scientist          PT Kamoro Maxima Integra
# 3             Data Scientist (Analytics)  PT Solusi Transportasi Indonesia
# 4                           Data Analyst                  Pengiklan Anonim
# ..                                   ...                               ...
# 103  Data & Application Operation Center          PT Jaya Teknik Indonesia
# 104                         Product Head          PT Cybertrend Intrabuana
# 105   Product Innovation Excellence Head          PT Cybertrend Intrabuana
# 106          Senior Technology Architect                  Finns Beach Club
# 107                 Data Analyst - Sales                     Kredivo Group
#
#            Lokasi                                    Gaji              Waktu  \
# 0    Jakarta Raya                   Gaji tidak disebutkan   5 hari yang lalu
# 1       Tangerang  Rp 8.500.000 – Rp 10.500.000 per month   1 hari yang lalu
# 2    Jakarta Raya                   Gaji tidak disebutkan   9 hari yang lalu
# 3    Jakarta Raya                   Gaji tidak disebutkan  16 hari yang lalu
# 4       Tangerang                   Gaji tidak disebutkan   5 hari yang lalu
# ..            ...                                     ...                ...
# 103  Jakarta Raya                   Gaji tidak disebutkan  25 hari yang lalu
# 104  Pasar Minggu                   Gaji tidak disebutkan  22 hari yang lalu
# 105  Pasar Minggu                   Gaji tidak disebutkan  22 hari yang lalu
# 106        Badung                   Gaji tidak disebutkan   6 hari yang lalu
# 107     Indonesia                   Gaji tidak disebutkan  13 hari yang lalu
#
#                                              Deskripsi
# 0    We are looking for a data scientist who is equ...
# 1    Career growth opportunity in a rapidly growing...
# 2    Minimum 5 years experience as Data Scientist, ...
# 3    You will use data to understand user needs and...
# 4                            Budaya kerja kekeluargaan
# ..                                                 ...
# 103  Pengalaman pekerjaan bidang IT selama minimal ...
# 104  CYBERTREND, as one of key player Data Science ...
# 105  At CYBERTREND, we believe that every company c...
# 106  FINNS World's Best Beach Club is more than a b...
# 107  Kredivo is looking for an experienced Data Ana...
#
# [108 rows x 6 columns]

# %%
def normalize_text(text):
    text = text.lower()  # Mengubah text menjadi huruf kecil
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # Menghapus karakter non-alfanumerik
    return text

# Menerapkan ke kolom "Deskripsi"
df['Deskripsi_Norm'] = df['Deskripsi'].apply(normalize_text)

# Tampilkan hasil
print("Hasil Setelah Normalisasi:")
display(df[['Deskripsi', 'Deskripsi_Norm']])
# Out:
# Hasil Setelah Normalisasi:
#                                              Deskripsi  \
# 0    We are looking for a data scientist who is equ...
# 1    Career growth opportunity in a rapidly growing...
# 2    Minimum 5 years experience as Data Scientist, ...
# 3    You will use data to understand user needs and...
# 4                            Budaya kerja kekeluargaan
# ..                                                 ...
# 103  Pengalaman pekerjaan bidang IT selama minimal ...
# 104  CYBERTREND, as one of key player Data Science ...
# 105  At CYBERTREND, we believe that every company c...
# 106  FINNS World's Best Beach Club is more than a b...
# 107  Kredivo is looking for an experienced Data Ana...
#
#                                         Deskripsi_Norm
# 0    we are looking for a data scientist who is equ...
# 1    career growth opportunity in a rapidly growing...
# 2    minimum 5 years experience as data scientist s...
# 3    you will use data to understand user needs and...
# 4                            budaya kerja kekeluargaan
# ..                                                 ...
# 103  pengalaman pekerjaan bidang it selama minimal ...
# 104  cybertrend as one of key player data science a...
# 105  at cybertrend we believe that every company ca...
# 106  finns worlds best beach club is more than a be...
# 107  kredivo is looking for an experienced data ana...
#
# [108 rows x 2 columns]

# %% [markdown]
# ## Penghapusan Stopword

# %%
# Bahasa Indonesia
# !pip install Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Bahasa Inggris
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Inisialisasi stopword remover
stopword_remover_id = StopWordRemoverFactory().create_stop_word_remover()
stop_words_en = set(stopwords.words('english'))

# Fungsi deteksi bahasa sederhana berdasarkan karakteristik kata
def detect_language(text):
    # Jika banyak kata umum bahasa Indonesia, anggap Bahasa Indonesia
    indo_keywords = ['dan', 'di', 'yang', 'untuk', 'dengan']
    count = sum(1 for word in text.lower().split() if word in indo_keywords)
    return 'id' if count > 1 else 'en'

# Fungsi gabungan penghapusan stopword
def remove_stopwords(text):
    lang = detect_language(text)
    if lang == 'id':
        return stopword_remover_id.remove(text)
    elif lang == 'en':
        words = word_tokenize(text)
        filtered = [word for word in words if word.lower() not in stop_words_en and word.isalnum()]
        return ' '.join(filtered)
    else:
        raise ValueError("Deteksi bahasa gagal. Pastikan teks menggunakan Bahasa Indonesia atau Inggris.")

# Terapkan langsung pada kolom Deskripsi (tanpa buat kolom baru)
df['Deskripsi_Stop'] = df['Deskripsi_Norm'].apply(remove_stopwords)

# Tampilkan hasil
print("Hasil Penghapusan Stopword (Otomatis ID/EN):")
display(df[['Deskripsi_Norm', 'Deskripsi_Stop']])
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.11/dist-packages (1.0.1)
# 🔹 Hasil Penghapusan Stopword (Otomatis ID/EN):
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                         Deskripsi_Norm  \
# 0    we are looking for a data scientist who is equ...
# 1    career growth opportunity in a rapidly growing...
# 2    minimum 5 years experience as data scientist s...
# 3    you will use data to understand user needs and...
# 4                            budaya kerja kekeluargaan
# ..                                                 ...
# 103  pengalaman pekerjaan bidang it selama minimal ...
# 104  cybertrend as one of key player data science a...
# 105  at cybertrend we believe that every company ca...
# 106  finns worlds best beach club is more than a be...
# 107  kredivo is looking for an experienced data ana...
#
#                                         Deskripsi_Stop
# 0    looking data scientist equally comfortable wri...
# 1    career growth opportunity rapidly growing company
# 2    minimum 5 years experience data scientist stro...
# 3    use data understand user needs defacto voice c...
# 4                            budaya kerja kekeluargaan
# ..                                                 ...
# 103  pengalaman pekerjaan bidang selama minimal 7 t...
# 104  cybertrend one key player data science ai comp...
# 105  cybertrend believe every company unlock full e...
# 106  finns worlds best beach club beach club destin...
# 107  kredivo looking experienced data analyst suppo...
#
# [108 rows x 2 columns]

# %% [markdown]
# ## Stemming

# %%
# Bahasa Indonesia
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Bahasa Inggris
from nltk.stem import SnowballStemmer

# Inisialisasi stemmer
stemmer_id = StemmerFactory().create_stemmer()
stemmer_en = SnowballStemmer("english")

# Fungsi deteksi bahasa (sama seperti sebelumnya)
def detect_language(text):
    indo_keywords = ['dan', 'di', 'yang', 'untuk', 'dengan']
    count = sum(1 for word in text.lower().split() if word in indo_keywords)
    return 'id' if count > 1 else 'en'

# Fungsi stemming gabungan
def stem_text(text):
    lang = detect_language(text)
    if lang == 'id':
        return stemmer_id.stem(text)
    elif lang == 'en':
        words = word_tokenize(text)
        stemmed = [stemmer_en.stem(word) for word in words if word.isalnum()]
        return ' '.join(stemmed)
    else:
        raise ValueError("Deteksi bahasa gagal. Pastikan teks menggunakan Bahasa Indonesia atau Inggris.")

# Terapkan langsung ke kolom Deskripsi
df['Deskripsi_Stem'] = df['Deskripsi_Stop'].apply(stem_text)

# Tampilkan hasil
print("Hasil Stemming (Otomatis ID/EN):")
display(df[['Deskripsi_Stop', 'Deskripsi_Stem']])
# Out:
# Hasil Stemming (Otomatis ID/EN):
#                                         Deskripsi_Stop  \
# 0    looking data scientist equally comfortable wri...
# 1    career growth opportunity rapidly growing company
# 2    minimum 5 years experience data scientist stro...
# 3    use data understand user needs defacto voice c...
# 4                            budaya kerja kekeluargaan
# ..                                                 ...
# 103  pengalaman pekerjaan bidang selama minimal 7 t...
# 104  cybertrend one key player data science ai comp...
# 105  cybertrend believe every company unlock full e...
# 106  finns worlds best beach club beach club destin...
# 107  kredivo looking experienced data analyst suppo...
#
#                                         Deskripsi_Stem
# 0    look data scientist equal comfort write sql qu...
# 1            career growth opportun rapid grow compani
# 2    minimum 5 year experi data scientist strong pr...
# 3    use data understand user need defacto voic cus...
# 4                            budaya kerja kekeluargaan
# ..                                                 ...
# 103  pengalaman pekerjaan bidang selama minim 7 tuj...
# 104  cybertrend one key player data scienc ai compa...
# 105  cybertrend believ everi compani unlock full ex...
# 106  finn world best beach club beach club destin v...
# 107  kredivo look experienc data analyst support an...
#
# [108 rows x 2 columns]

# %%
# Tampilkan Data hasil processing
df_data = display(df[['Posisi', 'Perusahaan', 'Lokasi', 'Gaji', 'Waktu', 'Deskripsi_Stem']])
df_data
# Out:
#                                   Posisi                        Perusahaan  \
# 0                         Data Scientist              PT Ninety Nine Dotco
# 1                  Junior Data Scientist             PT Fata Organa Solusi
# 2                  Senior Data Scientist          PT Kamoro Maxima Integra
# 3             Data Scientist (Analytics)  PT Solusi Transportasi Indonesia
# 4                           Data Analyst                  Pengiklan Anonim
# ..                                   ...                               ...
# 103  Data & Application Operation Center          PT Jaya Teknik Indonesia
# 104                         Product Head          PT Cybertrend Intrabuana
# 105   Product Innovation Excellence Head          PT Cybertrend Intrabuana
# 106          Senior Technology Architect                  Finns Beach Club
# 107                 Data Analyst - Sales                     Kredivo Group
#
#            Lokasi                                    Gaji              Waktu  \
# 0    Jakarta Raya                   Gaji tidak disebutkan   5 hari yang lalu
# 1       Tangerang  Rp 8.500.000 – Rp 10.500.000 per month   1 hari yang lalu
# 2    Jakarta Raya                   Gaji tidak disebutkan   9 hari yang lalu
# 3    Jakarta Raya                   Gaji tidak disebutkan  16 hari yang lalu
# 4       Tangerang                   Gaji tidak disebutkan   5 hari yang lalu
# ..            ...                                     ...                ...
# 103  Jakarta Raya                   Gaji tidak disebutkan  25 hari yang lalu
# 104  Pasar Minggu                   Gaji tidak disebutkan  22 hari yang lalu
# 105  Pasar Minggu                   Gaji tidak disebutkan  22 hari yang lalu
# 106        Badung                   Gaji tidak disebutkan   6 hari yang lalu
# 107     Indonesia                   Gaji tidak disebutkan  13 hari yang lalu
#
#                                         Deskripsi_Stem
# 0    look data scientist equal comfort write sql qu...
# 1            career growth opportun rapid grow compani
# 2    minimum 5 year experi data scientist strong pr...
# 3    use data understand user need defacto voic cus...
# 4                            budaya kerja kekeluargaan
# ..                                                 ...
# 103  pengalaman pekerjaan bidang selama minim 7 tuj...
# 104  cybertrend one key player data scienc ai compa...
# 105  cybertrend believ everi compani unlock full ex...
# 106  finn world best beach club beach club destin v...
# 107  kredivo look experienc data analyst support an...
#
# [108 rows x 6 columns]

# %%
# Menyimpan file full
df_data.to_csv('Full_Data_Job_Listings_Clean.csv', index=False)
